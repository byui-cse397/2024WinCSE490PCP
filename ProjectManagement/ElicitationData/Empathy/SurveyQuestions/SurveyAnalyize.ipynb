# %% [markdown]
# <a href="https://colab.research.google.com/github/awarbler/CSE490RPersonalDevelopment/blob/W04Branch/SurveyAnalyize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analyize Survey

# %% [markdown]
# |Feature| | |Yes|No|
# |:----|:----|:----|:----|:----|
# |Profile Page | |14|50%|42%|
# |Customize Board by Location| |14|70%|30%|
# |Social media| |14|62%|38%|
# |Ride Share -Ratings| | |78%| |
# |Moderation System| |13|90%| |
# |Sign In Features Easy to use| |5|35%| |
# |Sign In- Face ID| |2|14%| |
# |Sign In| |2|14%| |
# |Sign In- Two Factor| |4|29%| |
# |Sign In- Google Sign In| |2|14%| |
# |Create New Category| | |55%|30%|
# |See who Is online| | | |64%|
# |News Feed| |14|50%|50%|
# |Marketplace| |14| | |
# |Marketplace – clutter| | | |21%|
# |Marketplace – Enhance| | |14%| |
# |Marketplace| | |35.70%|21.4|
# |Marketplace separate feed| | |7.10%| |
# |Upload Images| |13|86%|14%|
# |See Owners of post| |7|50%| |
# |Forward Post| |14|57%|14%|
# |Time Date Location| |14|86.70%|6.7|
# |Date Location only| | | |6.7|
# |Security| |14|92.80%|7.1|
# |Private Message| |14|85%| |
# |Location| | |50%|50%|
# |Categorize post by location| |14|10%|90%|
# |Search Function| |14|90%|10%|
# |Chat to drivers| |14|78%| |
# |History Page| |14 |57% | |
# |Pick Up Service| 14|28% | 57%| |
# |Venmo Interface |8 | 50%| | |

# %% [markdown]
# # Raw Data
# | Timestamp          | What is your age? | What is your Gender? | What is your occupation?     | What are your interests?                                           | On a weekly basis, how frequently do you use online forums or community platforms for communication and collaboration? | How much time in the past week have you spent on a Community Board Apps? | How important is it for you to connect to other social media from the community board? Scale 1 -10 , 10 being the highest importance. | Would you like to have a profile page? Yes or no |  On a profile page would you like to have a feed for your interest? | Do you want to see when other users are online? | What are the main challenges you face when using existing community platforms or forums? | How important is it for you to have easy access to create new forum categories or sections based on specific needs or interests? “Not at all important,” “Slightly Important,” “Important,” “Fairly Important,” and “Very Important | What is your primary focus when you use community forums? | What features do you find essential in a sign-in process for online community platforms? | How valuable do you consider a moderation system to maintain the quality and safety of community discussions? | Would you find it beneficial to have specific criteria for posts in certain categories, such as a ride board, including details like car information, insurance status, and anonymous driver ratings? | How important is it for you to customize the community board based on your specific location or community, rather than being restricted to a predefined area? “Not at all important,” “Slightly Important,” “Important,” “Fairly Important,” and “Very Important | Do you think having a built-in marketplace feature within the community board would enhance or clutter the main discussion area? | How likely are you to report a post if you find it sketchy or inappropriate? What features would make the reporting process easier for you? |  Would you prefer to have the ability to upload photos to posts and forums to enhance communication and engagement? | How important is it for you to see the owner and all members associated with a post or forum discussion? “Not at all important,” “Slightly Important,” “Important,” “Fairly Important,” and “Very Important | Would you find it useful to refer people to specific posts or forums within the community board? How often would you use this feature? | Do you prefer having time, date, and location displayed on posts, especially when relevant to the discussion? | How important is user security and privacy to you when using online community platforms? “Not at all important,” “Slightly Important,” “Important,” “Fairly Important,” and “Very Important | Would you like the option to send private messages to other community members for more personalized communication? | How useful would it be for you to have location-based services integrated into the community board, such as determining your current location? | Do you have any preferences between categorizing posts by location (e.g., state or highway) or other criteria? | How important is it for you to have a robust search functionality to find specific posts or rides based on various criteria? “Not at all important,” “Slightly Important,” “Important,” “Fairly Important,” and “Very Important | Would you use a chat feature for direct communication between drivers and passengers? How essential is this feature to you? | How likely are you to use a rating system for drivers and passengers to provide feedback and enhance community trust? | How valuable would it be for you to have access to a history page to review past rides taken and given? “Not at all important,” “Slightly Important,” “Important,” “Fairly Important,” and “Very Important | Would you consider using a post feature for package pick-up services within the community board? | How familiar are you with social media-style interfaces like Venmo, and would you prefer a similar interface for the Community Board app? | Please Select Interviewer: |
# |--------------------|-------------------|----------------------|------------------------------|--------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------|---------------------------------------------------------------------|-------------------------------------------------|------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------|------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------|----------------------------|
# | 1/31/2024 17:58:57 | 35-44 years old.  | Female               | Student                      | Swim, crossfit, sports                                             | 3 – 4 times                                                                                                            | 30 minutes                                                               | Important                                                                                                                             | Yes                                              | Yes                                                                 | Yes                                             | No New Feed                                                                              | Important                                                                                                                                                                                                                           | Buying / Selling                                          | Two factor authentication                                                                | Very                                                                                                          | Yes                                                                                                                                                                                                   | Important                                                                                                                                                                                                                                                        | Yes                                                                                                                              | Unknown                                                                                                                                     | yes                                                                                                                 | important                                                                                                                                                                                                   | yes                                                                                                                                    | Yes                                                                                                           | Important                                                                                                                                                                                   | Yes                                                                                                                | Yes                                                                                                                                            | Yes                                                                                                            | Important                                                                                                                                                                                                                       | Yes                                                                                                                         | Likely                                                                                                                | Important                                                                                                                                                                                                  | Yes                                                                                              | Maybe Use                                                                                                                                 | Anita                      |
# | 1/31/2024 19:47:53 | 25-34 years old.  | Male                 | Digital Marketing Manager    | Reading, Programming, Embedded Systems, Playing with my kids       | 3 – 4 times                                                                                                            | 1 - 2 hours                                                              | Not                                                                                                                                   | Yes                                              | Yes                                                                 | No                                              | Password                                                                                 | Slightly                                                                                                                                                                                                                            | Social Issues                                             | Ease of Use                                                                              | Very                                                                                                          | Yes                                                                                                                                                                                                   | Fairly                                                                                                                                                                                                                                                           | Yes                                                                                                                              | Somewhat                                                                                                                                    | Yes                                                                                                                 | Fairly                                                                                                                                                                                                      | Yes                                                                                                                                    | Yes                                                                                                           | Important                                                                                                                                                                                   | Yes                                                                                                                | Slightly                                                                                                                                       | No                                                                                                             | Important                                                                                                                                                                                                                       | Yes                                                                                                                         | Likely                                                                                                                | Important                                                                                                                                                                                                  | Unknown                                                                                          | Familiar                                                                                                                                  | Andrew                     |
# | 2/1/2024 14:55:20  | 25-34 years old.  | Female               | Dental hygienist             | Sports and nature                                                  | 3 – 4 times                                                                                                            | 1 - 2 hours                                                              | Fairly                                                                                                                                | Yes                                              | Yes                                                                 | Yes                                             | Username                                                                                 | Very                                                                                                                                                                                                                                | Networking                                                | Ease of Use                                                                              | Very                                                                                                          | Yes                                                                                                                                                                                                   | Very                                                                                                                                                                                                                                                             | Yes                                                                                                                              | Somewhat                                                                                                                                    | Yes                                                                                                                 | Very                                                                                                                                                                                                        | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Very                                                                                                                                           | No                                                                                                             | Somewhat                                                                                                                                                                                                                        | Yes                                                                                                                         | Likely                                                                                                                | Very                                                                                                                                                                                                       | No                                                                                               | Somewhat                                                                                                                                  | Anita                      |
# | 2/1/2024 15:20:32  | 45-64 years old.  | Male                 | Electrical engineer          | reading, studying languages                                        | None                                                                                                                   | 0                                                                        | Slightly                                                                                                                              | No                                               | Yes                                                                 | No                                              | Ads                                                                                      | Not                                                                                                                                                                                                                                 | Events                                                    | FaceId                                                                                   | Important                                                                                                     | Yes                                                                                                                                                                                                   | Not                                                                                                                                                                                                                                                              | Enhance                                                                                                                          | Likely                                                                                                                                      | Yes                                                                                                                 | important                                                                                                                                                                                                   | Yes                                                                                                                                    | Yes                                                                                                           | Important                                                                                                                                                                                   | No                                                                                                                 | Fairly                                                                                                                                         | No                                                                                                             | Important                                                                                                                                                                                                                       | Yes                                                                                                                         | Likely                                                                                                                | Important                                                                                                                                                                                                  | Maybe Not                                                                                        | Familiar                                                                                                                                  | Anita                      |
# | 2/1/2024 15:22:06  | 25-34 years old.  | Male                 | College Student              | Friends, Games, Writing, books                                     | More than 6                                                                                                            | 3 - 4 hours                                                              | Fairly                                                                                                                                | Yes                                              | No                                                                  | Yes                                             | Finding Post                                                                             | Very                                                                                                                                                                                                                                | Events                                                    | Login, name, username as well                                                            | Very                                                                                                          | Yes                                                                                                                                                                                                   | Very                                                                                                                                                                                                                                                             | No                                                                                                                               | Very Likely                                                                                                                                 | Yes                                                                                                                 | Very                                                                                                                                                                                                        | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Very                                                                                                                                           | No                                                                                                             | Very                                                                                                                                                                                                                            | Yes                                                                                                                         | Very Likely                                                                                                           | Very                                                                                                                                                                                                       | No                                                                                               | Not Familiar                                                                                                                              | Darcy                      |
# | 2/1/2024 18:33:57  | 25-34 years old.  | Male                 | Student                      | Sports, welding, programming, computers, video games               | 3 – 4 times                                                                                                            | 30 minutes                                                               | Not                                                                                                                                   | Yes                                              | No                                                                  | No                                              | Unfamiliar                                                                               | Fairly                                                                                                                                                                                                                              | Buying / Selling                                          | Google Sign In                                                                           | Fairy                                                                                                         | Yes                                                                                                                                                                                                   | Fairly                                                                                                                                                                                                                                                           | Clutter                                                                                                                          | Very Likely                                                                                                                                 | Yes                                                                                                                 | Slightly                                                                                                                                                                                                    | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Very                                                                                                                                           | Yes                                                                                                            | Fairly                                                                                                                                                                                                                          | Yes                                                                                                                         | Very likely                                                                                                           | Fairly                                                                                                                                                                                                     | No                                                                                               | Use Maybe                                                                                                                                 | Anita                      |
# | 2/1/2024 21:39:02  | undisclosed       | undisclosed          | Occupied                     | Diverse                                                            | More than 6                                                                                                            | 0                                                                        | Not                                                                                                                                   | No                                               | No                                                                  | No                                              | Ads                                                                                      | Not                                                                                                                                                                                                                                 | Communication                                             | Broad adoption                                                                           | Slightly                                                                                                      | No                                                                                                                                                                                                    | It depends on what one defines a "community board" as or what one expects it to facilitate.                                                                                                                                                                      | No                                                                                                                               | Add Button                                                                                                                                  | No                                                                                                                  | Not                                                                                                                                                                                                         | No                                                                                                                                     | There is no reason that this is ubiquitous among social media platforms.                                      | Slightly                                                                                                                                                                                    | No                                                                                                                 | Not                                                                                                                                            | No                                                                                                             | Not                                                                                                                                                                                                                             | A community board should not promote ridesharing.                                                                           | Not                                                                                                                   | Not                                                                                                                                                                                                        | No                                                                                               | Not Familiar                                                                                                                              | This survey                |
# | 2/1/2024 23:47:33  | 65-74 years old.  | Male                 | Retired electronics engineer | Music, photography, current events, trail hiking                   | 3 – 4 times                                                                                                            | 30 minutes                                                               | Not                                                                                                                                   | Undecided                                        | No                                                                  | No                                              | None                                                                                     | Not                                                                                                                                                                                                                                 | Announcement                                              | Password Protection                                                                      | Very                                                                                                          | No                                                                                                                                                                                                    | Fairly                                                                                                                                                                                                                                                           | Clutter                                                                                                                          | Somewhat                                                                                                                                    | Yes                                                                                                                 | Fairly                                                                                                                                                                                                      | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Not                                                                                                                                            | No                                                                                                             | Not                                                                                                                                                                                                                             | Yes                                                                                                                         | Very Likely                                                                                                           | Not                                                                                                                                                                                                        | Maybe Yes                                                                                        | Not Familiar                                                                                                                              | Anita                      |
# | 2/1/2024 23:59:53  | 65-74 years old.  | Female               | Security Officer             | Jesus Christ, Church, My Horses, Nature, Music, Reading, My Family | More than 6                                                                                                            | 1 - 2 hours                                                              | Important                                                                                                                             | Yes                                              | Yes                                                                 | Yes                                             | None                                                                                     | Not                                                                                                                                                                                                                                 | Events                                                    | Not sure                                                                                 | Important                                                                                                     | Yes                                                                                                                                                                                                   | Important                                                                                                                                                                                                                                                        | Yes                                                                                                                              | Very Likely                                                                                                                                 | Yes                                                                                                                 | Very                                                                                                                                                                                                        | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Slightly                                                                                                                                       | No                                                                                                             | Very                                                                                                                                                                                                                            | Yes                                                                                                                         | Likely                                                                                                                | Important                                                                                                                                                                                                  | Maybe Yes                                                                                        | Not Familiar                                                                                                                              | Anita                      |
# | 2/2/2024 8:16:03   | 45-64 years old.  | Female               | Retired                      | Sewing, puzzles, pilates                                           | 5 - 6 times                                                                                                            | None                                                                     | Slightly                                                                                                                              | No                                               | Yes                                                                 | No                                              | Comments                                                                                 | Important                                                                                                                                                                                                                           | Current Info                                              | Two factor authentication                                                                | Very                                                                                                          | Yes                                                                                                                                                                                                   | Slightly                                                                                                                                                                                                                                                         | Seperate Feed                                                                                                                    | Not Likely                                                                                                                                  | Yes                                                                                                                 | Fairly                                                                                                                                                                                                      | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Important                                                                                                                                      | No                                                                                                             | Very                                                                                                                                                                                                                            | Yes                                                                                                                         | Very Likely                                                                                                           | Fairly                                                                                                                                                                                                     | No                                                                                               | Very Familiar                                                                                                                             | Anita                      |
# | 2/2/2024 10:13:08  | 45-64 years old.  | Female               | Homemaker                    | Hiking, Reading, Canoeing, Traveling, Family History, Singing      | 3 – 4 times                                                                                                            | 30 minutes                                                               | Slightly                                                                                                                              | No                                               | No                                                                  | No                                              | Complaints                                                                               | Important                                                                                                                                                                                                                           | Current Info                                              | Two factor authentication                                                                | Very                                                                                                          | Yes                                                                                                                                                                                                   | Fairly                                                                                                                                                                                                                                                           | Clutter                                                                                                                          | Likely                                                                                                                                      | Yes                                                                                                                 | Very                                                                                                                                                                                                        | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Not                                                                                                                                            | No                                                                                                             | Very                                                                                                                                                                                                                            | Yes                                                                                                                         | Fairly Likely                                                                                                         | Fairly                                                                                                                                                                                                     | No                                                                                               | Fairly Familiar                                                                                                                           | Anita                      |
# | 2/2/2024 12:37:07  | 65-74 years old.  | Female               | Retired                      | Gardening, quilting, book club                                     | More than 6                                                                                                            | 1 - 2 hours                                                              | Fairly                                                                                                                                | No                                               | No                                                                  | No                                              | Social Media Errors                                                                      | Important                                                                                                                                                                                                                           | Road Conditions                                           | Google Sign In                                                                           | Indispensable                                                                                                 | No                                                                                                                                                                                                    | Very                                                                                                                                                                                                                                                             | No                                                                                                                               | Very Likely                                                                                                                                 | Yes                                                                                                                 | Slightly                                                                                                                                                                                                    | No                                                                                                                                     | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Not                                                                                                                                            | No                                                                                                             | Very                                                                                                                                                                                                                            | No                                                                                                                          | Not                                                                                                                   | Not                                                                                                                                                                                                        | No                                                                                               | Not Familiar                                                                                                                              | Allan                      |
# | 2/2/2024 13:19:36  | 45-64 years old.  | Male                 | Program Manager              | gardening, physical fitness, technology                            | 3 – 4 times                                                                                                            | 30 minutes                                                               | Slightly                                                                                                                              | Yes                                              | Yes                                                                 | Yes                                             | Ads                                                                                      | Slightly                                                                                                                                                                                                                            | Information                                               | Secure                                                                                   | Very                                                                                                          | Yes                                                                                                                                                                                                   | Important                                                                                                                                                                                                                                                        | Yes                                                                                                                              | Somewhat                                                                                                                                    | Yes                                                                                                                 | Very                                                                                                                                                                                                        | Maybe                                                                                                                                  | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Very                                                                                                                                           | prefer topic of interest                                                                                       | Very                                                                                                                                                                                                                            | Yes                                                                                                                         | Likely                                                                                                                | Very                                                                                                                                                                                                       | Yes                                                                                              | Somewhat                                                                                                                                  | Anita                      |
# | 2/3/2024 6:57:31   | 45-64 years old.  | Female               | Social worker                | Gardening, animals, social justice                                 | 3 – 4 times                                                                                                            | 1 - 2 hours                                                              | Not                                                                                                                                   | No                                               | No                                                                  | No                                              | Discussions Lost                                                                         | Slightly                                                                                                                                                                                                                            | Social Issues                                             | Secure                                                                                   | Very                                                                                                          | Yes                                                                                                                                                                                                   | Slightly                                                                                                                                                                                                                                                         | Enhance                                                                                                                          | Likely                                                                                                                                      | Yes                                                                                                                 | Fairly                                                                                                                                                                                                      | Yes                                                                                                                                    | Yes                                                                                                           | Very                                                                                                                                                                                        | Yes                                                                                                                | Important                                                                                                                                      | Yes                                                                                                            | Very                                                                                                                                                                                                                            | No                                                                                                                          | Very Likely                                                                                                           | Very                                                                                                                                                                                                       | No                                                                                               | Yes                                                                                                                                       | Anita                      |
# | Summarize          |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     | Road Conditions                                           | Two factor authentication                                                                |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  | Add Button                                                                                                                                  |                                                                                                                     |                                                                                                                                                                                                             | Share button                                                                                                                           | Date and location                                                                                             |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  | No                                                                                                                                        |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     | Connecting                                                | Remember SignIn                                                                          |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  | Add Button                                                                                                                                  |                                                                                                                     |                                                                                                                                                                                                             | Share button                                                                                                                           |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  | Familiar                                                                                                                                  |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     | Learning                                                  | FaceId                                                                                   |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  | Add Button                                                                                                                                  |                                                                                                                     |                                                                                                                                                                                                             | Share button                                                                                                                           |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  | No                                                                                                                                        |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     | Buying / Selling                                          | AppleId                                                                                  |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  |                                                                                                                                             |                                                                                                                     |                                                                                                                                                                                                             | Share button                                                                                                                           |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  | No                                                                                                                                        |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     |                                                           | Ease of Use                                                                              |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  |                                                                                                                                             |                                                                                                                     |                                                                                                                                                                                                             | Share button                                                                                                                           |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  | No                                                                                                                                        |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     |                                                           | Two factor authentication                                                                |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  |                                                                                                                                             |                                                                                                                     |                                                                                                                                                                                                             | Easy                                                                                                                                   |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  | Yes                                                                                                                                       |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     |                                                           | Secure                                                                                   |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  |                                                                                                                                             |                                                                                                                     |                                                                                                                                                                                                             |                                                                                                                                        |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  |                                                                                                                                           |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     |                                                           | Ease of Use                                                                              |                                                                                                               |                                                                                                                                                                                                       |                                                                                                                                                                                                                                                                  |                                                                                                                                  |                                                                                                                                             |                                                                                                                     |                                                                                                                                                                                                             |                                                                                                                                        |                                                                                                               |                                                                                                                                                                                             |                                                                                                                    |                                                                                                                                                |                                                                                                                |                                                                                                                                                                                                                                 |                                                                                                                             |                                                                                                                       |                                                                                                                                                                                                            |                                                                                                  |                                                                                                                                           |                            |
# |                    |                   |                      |                              |                                                                    |                                                                                                                        |                                                                          |                                                                                                                                       |                                                  |                                                                     |                                                 |                                                                                          |                                                                                                                                                                                                                                     |                                                           | Ease of Use                                                                              |

# %% [markdown]
# # Graphs and Pie Charts

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
